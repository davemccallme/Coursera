# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# # Accessing Databases with SQL Magic
#
# Estimated time needed: **15** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Perform simplified database access using SQL "magic"

# %% [markdown]
# ##### To communicate with SQL Databases from within a JupyterLab notebook, we can use the SQL "magic" provided by the [ipython-sql](https://github.com/catherinedevlin/ipython-sql) extension. "Magic" is JupyterLab's term for special commands that start with "%". Below, we'll use the *load*\_*ext* magic to load the ipython-sql extension. In the lab environemnt provided in the course the ipython-sql extension is already installed and so is the ibm_db_sa driver.

# %%
# %load_ext sql

# %% [markdown]
# ##### Here  you will  be creating and connecting to a new SQlite database SQLiteMagic.
#
# ##### The syntax for connecting to magic sql using sqllite is
#
#   **%sql sqlite://DatabaseName**
#
# where DatabaseName will be your **.db** file

# %%
import csv, sqlite3

con = sqlite3.connect("SQLiteMagic.db")
cur = con.cursor()

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///SQLiteMagic.db

# %% [markdown]
# ##### For convenience, we can use %%sql (two %'s instead of one) at the top of a cell to indicate we want the entire cell to be treated as SQL. Let's use this to create a table and fill it with some test data for experimenting.

# %%
# %%sql
#
# CREATE TABLE INTERNATIONAL_STUDENT_TEST_SCORES (
# 	country VARCHAR(50),
# 	first_name VARCHAR(50),
# 	last_name VARCHAR(50),
# 	test_score INT
# );
# INSERT INTO INTERNATIONAL_STUDENT_TEST_SCORES (country, first_name, last_name, test_score)
# VALUES
# ('United States', 'Marshall', 'Bernadot', 54),
# ('Ghana', 'Celinda', 'Malkin', 51),
# ('Ukraine', 'Guillermo', 'Furze', 53),
# ('Greece', 'Aharon', 'Tunnow', 48),
# ('Russia', 'Bail', 'Goodwin', 46),
# ('Poland', 'Cole', 'Winteringham', 49),
# ('Sweden', 'Emlyn', 'Erricker', 55),
# ('Russia', 'Cathee', 'Sivewright', 49),
# ('China', 'Barny', 'Ingerson', 57),
# ('Uganda', 'Sharla', 'Papaccio', 55),
# ('China', 'Stella', 'Youens', 51),
# ('Poland', 'Julio', 'Buesden', 48),
# ('United States', 'Tiffie', 'Cosely', 58),
# ('Poland', 'Auroora', 'Stiffell', 45),
# ('China', 'Clarita', 'Huet', 52),
# ('Poland', 'Shannon', 'Goulden', 45),
# ('Philippines', 'Emylee', 'Privost', 50),
# ('France', 'Madelina', 'Burk', 49),
# ('China', 'Saunderson', 'Root', 58),
# ('Indonesia', 'Bo', 'Waring', 55),
# ('China', 'Hollis', 'Domotor', 45),
# ('Russia', 'Robbie', 'Collip', 46),
# ('Philippines', 'Davon', 'Donisi', 46),
# ('China', 'Cristabel', 'Radeliffe', 48),
# ('China', 'Wallis', 'Bartleet', 58),
# ('Moldova', 'Arleen', 'Stailey', 38),
# ('Ireland', 'Mendel', 'Grumble', 58),
# ('China', 'Sallyann', 'Exley', 51),
# ('Mexico', 'Kain', 'Swaite', 46),
# ('Indonesia', 'Alonso', 'Bulteel', 45),
# ('Armenia', 'Anatol', 'Tankus', 51),
# ('Indonesia', 'Coralyn', 'Dawkins', 48),
# ('China', 'Deanne', 'Edwinson', 45),
# ('China', 'Georgiana', 'Epple', 51),
# ('Portugal', 'Bartlet', 'Breese', 56),
# ('Azerbaijan', 'Idalina', 'Lukash', 50),
# ('France', 'Livvie', 'Flory', 54),
# ('Malaysia', 'Nonie', 'Borit', 48),
# ('Indonesia', 'Clio', 'Mugg', 47),
# ('Brazil', 'Westley', 'Measor', 48),
# ('Philippines', 'Katrinka', 'Sibbert', 51),
# ('Poland', 'Valentia', 'Mounch', 50),
# ('Norway', 'Sheilah', 'Hedditch', 53),
# ('Papua New Guinea', 'Itch', 'Jubb', 50),
# ('Latvia', 'Stesha', 'Garnson', 53),
# ('Canada', 'Cristionna', 'Wadmore', 46),
# ('China', 'Lianna', 'Gatward', 43),
# ('Guatemala', 'Tanney', 'Vials', 48),
# ('France', 'Alma', 'Zavittieri', 44),
# ('China', 'Alvira', 'Tamas', 50),
# ('United States', 'Shanon', 'Peres', 45),
# ('Sweden', 'Maisey', 'Lynas', 53),
# ('Indonesia', 'Kip', 'Hothersall', 46),
# ('China', 'Cash', 'Landis', 48),
# ('Panama', 'Kennith', 'Digance', 45),
# ('China', 'Ulberto', 'Riggeard', 48),
# ('Switzerland', 'Judy', 'Gilligan', 49),
# ('Philippines', 'Tod', 'Trevaskus', 52),
# ('Brazil', 'Herold', 'Heggs', 44),
# ('Latvia', 'Verney', 'Note', 50),
# ('Poland', 'Temp', 'Ribey', 50),
# ('China', 'Conroy', 'Egdal', 48),
# ('Japan', 'Gabie', 'Alessandone', 47),
# ('Ukraine', 'Devlen', 'Chaperlin', 54),
# ('France', 'Babbette', 'Turner', 51),
# ('Czech Republic', 'Virgil', 'Scotney', 52),
# ('Tajikistan', 'Zorina', 'Bedow', 49),
# ('China', 'Aidan', 'Rudeyeard', 50),
# ('Ireland', 'Saunder', 'MacLice', 48),
# ('France', 'Waly', 'Brunstan', 53),
# ('China', 'Gisele', 'Enns', 52),
# ('Peru', 'Mina', 'Winchester', 48),
# ('Japan', 'Torie', 'MacShirrie', 50),
# ('Russia', 'Benjamen', 'Kenford', 51),
# ('China', 'Etan', 'Burn', 53),
# ('Russia', 'Merralee', 'Chaperlin', 38),
# ('Indonesia', 'Lanny', 'Malam', 49),
# ('Canada', 'Wilhelm', 'Deeprose', 54),
# ('Czech Republic', 'Lari', 'Hillhouse', 48),
# ('China', 'Ossie', 'Woodley', 52),
# ('Macedonia', 'April', 'Tyer', 50),
# ('Vietnam', 'Madelon', 'Dansey', 53),
# ('Ukraine', 'Korella', 'McNamee', 52),
# ('Jamaica', 'Linnea', 'Cannam', 43),
# ('China', 'Mart', 'Coling', 52),
# ('Indonesia', 'Marna', 'Causbey', 47),
# ('China', 'Berni', 'Daintier', 55),
# ('Poland', 'Cynthia', 'Hassell', 49),
# ('Canada', 'Carma', 'Schule', 49),
# ('Indonesia', 'Malia', 'Blight', 48),
# ('China', 'Paulo', 'Seivertsen', 47),
# ('Niger', 'Kaylee', 'Hearley', 54),
# ('Japan', 'Maure', 'Jandak', 46),
# ('Argentina', 'Foss', 'Feavers', 45),
# ('Venezuela', 'Ron', 'Leggitt', 60),
# ('Russia', 'Flint', 'Gokes', 40),
# ('China', 'Linet', 'Conelly', 52),
# ('Philippines', 'Nikolas', 'Birtwell', 57),
# ('Australia', 'Eduard', 'Leipelt', 53)
# Out:
#  * sqlite:///SQLiteMagic.db
# (sqlite3.OperationalError) table INTERNATIONAL_STUDENT_TEST_SCORES already exists
# [SQL: CREATE TABLE INTERNATIONAL_STUDENT_TEST_SCORES (
# 	country VARCHAR(50),
# 	first_name VARCHAR(50),
# 	last_name VARCHAR(50),
# 	test_score INT
# );]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# #### Using Python Variables in your SQL Statements
#
# ##### You can use python variables in your SQL statements by adding a ":" prefix to your python variable names.
#
# ##### For example, if I have a python variable `country` with a value of `"Canada"`, I can use this variable in a SQL query to find all the rows of students from Canada.

# %%
country = "Canada"
# %sql select * from INTERNATIONAL_STUDENT_TEST_SCORES where country = :country
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# [('Canada', 'Cristionna', 'Wadmore', 46),
#  ('Canada', 'Wilhelm', 'Deeprose', 54),
#  ('Canada', 'Carma', 'Schule', 49)]

# %% [markdown]
# #### Assigning the Results of Queries to Python Variables

# %% [markdown]
# ##### You can use the normal python assignment syntax to assign the results of your queries to python variables.
#
# ##### For example, I have a SQL query to retrieve the distribution of test scores (i.e. how many students got each score). I can assign the result of this query to the variable `test_score_distribution` using the `=` operator.

# %%
import pandas as pd
test_score_distribution = %sql SELECT test_score as "Test_Score", count(*) as "Frequency" from INTERNATIONAL_STUDENT_TEST_SCORES GROUP BY test_score;
print(type(test_score_distribution))
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# <class 'sql.run.ResultSet'>

# %% [markdown]
# #### Converting Query Results to DataFrames

# %% [markdown]
# ##### You can easily convert a SQL query result to a pandas dataframe using the `DataFrame()` method. Dataframe objects are much more versatile than SQL query result objects. For example, we can easily graph our test score distribution after converting to a dataframe.

# %%
dataframe = test_score_distribution.DataFrame()

# %pip install matplotlib
# %matplotlib inline
# uncomment the following line if you get an module error saying seaborn not found
# %pip install seaborn==0.9.0
import seaborn

#plot1 = seaborn.barplot(x='Test_Score',y='Frequency', data=dataframe)
#plot2 = seaborn.catplot(x='Country',y='Test_Score', data=dataframe)
#plot3 = seaborn.stripplot(x='Country',y='Test_Score', data=dataframe)
#plot4 = seaborn.swarmplot(x='Country',y='Test_Score', data=dataframe)
# Out:
# Requirement already satisfied: matplotlib in c:\users\admin\mambaforge\lib\site-packages (3.7.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\mambaforge\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\mambaforge\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\mambaforge\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: numpy>=1.20 in c:\users\admin\mambaforge\lib\site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\mambaforge\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\mambaforge\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\mambaforge\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn==0.9.0 in c:\users\admin\mambaforge\lib\site-packages (0.9.0)
# Requirement already satisfied: scipy>=0.14.0 in c:\users\admin\mambaforge\lib\site-packages (from seaborn==0.9.0) (1.10.1)
# Requirement already satisfied: numpy>=1.9.3 in c:\users\admin\mambaforge\lib\site-packages (from seaborn==0.9.0) (1.24.2)
# Requirement already satisfied: matplotlib>=1.4.3 in c:\users\admin\mambaforge\lib\site-packages (from seaborn==0.9.0) (3.7.1)
# Requirement already satisfied: pandas>=0.15.2 in c:\users\admin\mambaforge\lib\site-packages (from seaborn==0.9.0) (1.5.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\mambaforge\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\mambaforge\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\mambaforge\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\mambaforge\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\mambaforge\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\mambaforge\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\mambaforge\lib\site-packages (from pandas>=0.15.2->seaborn==0.9.0) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->seaborn==0.9.0) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now you know how to work with Db2 from within JupyterLab notebooks using SQL "magic"!

# %%
from sqlalchemy import text

query = con.execute(text("SELECT country, first_name, last_name, test_score FROM INTERNATIONAL_STUDENT_TEST_SCORES"))

# get query result as a list of tuples
result = query.fetchall()

# %%
# create DataFrame with column names from SQL
df = pd.DataFrame(result, columns=query.keys())

# close database connection
con.close()

print(df['country'], type(df['country']))
# Out:
# 0     United States
# 1             Ghana
# 2           Ukraine
# 3            Greece
# 4            Russia
#           ...
# 94        Venezuela
# 95           Russia
# 96            China
# 97      Philippines
# 98        Australia
# Name: country, Length: 99, dtype: object <class 'pandas.core.series.Series'>

# %%
print(type(df))
print(list(df.columns))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ['country', 'first_name', 'last_name', 'test_score']

# %% [markdown]
# Load the data into a world heat map

# %%
# %pip install geopandas
# %pip install pycountry
import geopandas as gpd
import matplotlib.pyplot as plt
import pycountry
# Out:
# Collecting geopandas
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      - -------------------------------------- 0.0/1.1 MB 279.3 kB/s eta 0:00:04
#      - -------------------------------------- 0.0/1.1 MB 279.3 kB/s eta 0:00:04
#      -- ------------------------------------- 0.1/1.1 MB 326.8 kB/s eta 0:00:03
#      ----- ---------------------------------- 0.2/1.1 MB 610.0 kB/s eta 0:00:02
#      --------- ------------------------------ 0.3/1.1 MB 871.5 kB/s eta 0:00:01
#      ---------- ----------------------------- 0.3/1.1 MB 803.7 kB/s eta 0:00:01
#      --------------- ------------------------ 0.4/1.1 MB 1.0 MB/s eta 0:00:01
#      ------------------ --------------------- 0.5/1.1 MB 1.1 MB/s eta 0:00:01
#      --------------------- ------------------ 0.6/1.1 MB 1.2 MB/s eta 0:00:01
#      --------------------------- ------------ 0.7/1.1 MB 1.3 MB/s eta 0:00:01
#      -------------------------------- ------- 0.8/1.1 MB 1.5 MB/s eta 0:00:01
#      ------------------------------------- -- 1.0/1.1 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------- 1.1/1.1 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.0 in c:\users\admin\mambaforge\lib\site-packages (from geopandas) (1.5.3)
# Requirement already satisfied: packaging in c:\users\admin\appdata\roaming\python\python310\site-packages (from geopandas) (23.0)
# Collecting pyproj>=2.6.1.post1
#   Downloading pyproj-3.4.1-cp310-cp310-win_amd64.whl (4.8 MB)
#      ---------------------------------------- 0.0/4.8 MB ? eta -:--:--
#       --------------------------------------- 0.1/4.8 MB 3.2 MB/s eta 0:00:02
#      - -------------------------------------- 0.2/4.8 MB 2.1 MB/s eta 0:00:03
#      -- ------------------------------------- 0.3/4.8 MB 2.8 MB/s eta 0:00:02
#      ---- ----------------------------------- 0.5/4.8 MB 3.0 MB/s eta 0:00:02
#      ----- ---------------------------------- 0.6/4.8 MB 2.8 MB/s eta 0:00:02
#      ------ --------------------------------- 0.7/4.8 MB 2.9 MB/s eta 0:00:02
#      ------ --------------------------------- 0.8/4.8 MB 2.8 MB/s eta 0:00:02
#      -------- ------------------------------- 1.0/4.8 MB 2.9 MB/s eta 0:00:02
#      --------- ------------------------------ 1.1/4.8 MB 2.9 MB/s eta 0:00:02
#      ---------- ----------------------------- 1.3/4.8 MB 3.0 MB/s eta 0:00:02
#      ------------ --------------------------- 1.5/4.8 MB 3.0 MB/s eta 0:00:02
#      ------------- -------------------------- 1.6/4.8 MB 3.1 MB/s eta 0:00:02
#      -------------- ------------------------- 1.8/4.8 MB 3.0 MB/s eta 0:00:02
#      ---------------- ----------------------- 1
kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.0 kB 130.7 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.0 kB 130.7 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.0 kB 130.7 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.0 kB 130.7 kB/s eta 0:00:01
#      --------------------------------- ----- 51.2/60.0 kB 67.1 kB/s eta 0:00:01
#      --------------------------------------- 60.0/60.0 kB 79.6 kB/s eta 0:00:00
# Collecting click~=8.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ---------------------------------------- 0.0/96.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/96.6 kB ? eta -:--:--
#      ------------ --------------------------- 30.7/96.6 kB ? eta -:--:--
#      ---------------------------------------- 96.6/96.6 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi in c:\users\admin\mambaforge\lib\site-packages (from fiona>=1.8->geopandas) (2022.12.7)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: setuptools in c:\users\admin\mambaforge\lib\site-packages (from fiona>=1.8->geopandas) (65.6.3)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\mambaforge\lib\site-packages (from pandas>=1.0.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\admin\mambaforge\lib\site-packages (from pandas>=1.0.0->geopandas) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\admin\appdata\roaming\python\python310\site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: colorama in c:\users\admin\appdata\roaming\python\python310\site-packages (from click~=8.0->fiona>=1.8->geopandas) (0.4.6)
# Requirement already satisfied: six in c:\users\admin\appdata\roaming\python\python310\site-packages (from munch>=2.3.2->fiona>=1.8->geopandas) (1.16.0)
# Installing collected packages: shapely, pyproj, munch, click, attrs, cligj, click-plugins, fiona, geopandas
# Successfully installed attrs-22.2.0 click-8.1.3 click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.1 geopandas-0.12.2 munch-2.5.0 pyproj-3.4.1 shapely-2.0.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 12.0 kB/s eta 0:14:01
#      ---------------------------------------- 0.0/10.1 MB 6.9 kB/s eta 0:24:19
#      ---------------------------------------- 0.0/10.1 MB 6.9 kB/s eta 0:24:19
#      ---------------------------------------- 0.0/10.1 MB 6.9 kB/s eta 0:24:19
#      ---------------------------------------- 0.1/10.1 MB 11.2 kB/s eta 0:15:02
#      ---------------------------------------- 0.1/10.1 MB 11.2 kB/s eta 0:15:02
#      ---------------------------------------- 0.1/10.1 MB 11.2 kB/s eta 0:15:02
#      ---------------------------------------- 0.1/10.1 MB 11.2 kB/s eta 0:15:02
#      ---------------------------------------- 0.1/10.1 MB 11.2 kB/s eta 0:15:02
#      ---------------------------------------- 0.1/10.1 MB 11.2 kB/s eta 0:15:02
#      ---------------------------------------- 0.1/10.1 MB 12.6 kB/s eta 0:13:22
#      ---------------------------------------- 0.1/10.1 MB 12.6 kB/s eta 0:13:22
#      ---------------------------------------- 0.1/10.1 MB 12.6 kB/s eta 0:13:22
#      ---------------------------------------- 0.1/10.1 MB 12.6 kB/s eta 0:13:22
#      ---------------------------------------- 0.1/10.1 MB 16.2 kB/s eta 0:10:21
#      ---------------------------------------- 0.1/10.1 MB 16.2 kB/s eta 0:10:21
#      ---------------------------------------- 0.1/10.1 MB 19.8 kB/s eta 0:08:27
#      ---------------------------------------- 0.1/10.1 MB 19.8 kB/s eta 0:08:27
#      ---------------------------------------- 0.1/10.1 MB 21.4 kB/s eta 0:07:49
#      ---------------------------------------- 0.1/10.1 MB 21.4 kB/s eta 0:07:49
#       --------------------------------------- 0.1/10.1 MB 24.9 kB/s eta 0:06:42
#       --------------------------------------- 0.1/10.1 MB 24.9 kB/s eta 0:06:42
#       --------------------------------------- 0.2/10.1 MB 26.2 kB/s eta 0:06:21
#       --------------------------------------- 0.2/10.1 MB 26.2 kB/s eta 0:06:21
#       --------------------------------------- 0.2/10.1 MB 26.2 kB/s eta 0:06:21
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use pycountry to rename the country column for the world map merge
# create a dictionary of country names and their corresponding 3-letter codes
countries = {}
for country in pycountry.countries:
    countries[country.name] = country.alpha_3

# replace country names in the dataframe with their corresponding 3-letter codes and fill blanks
df_country = df['country'].map(countries).fillna('N/A')

print(type(df_country),df_country.head())
# Out:
# <class 'pandas.core.series.Series'> 0    USA
# 1    GHA
# 2    UKR
# 3    GRC
# 4    N/A
# Name: country, dtype: object

# %%
# check the number of rows with NaN values
num_nan_rows = df_country.isna().sum()
print(f"Number of rows with NaN values: {num_nan_rows}")
# Out:
# Number of rows with NaN values: 0

# %%
#convert series to Dataframe
df_country = pd.DataFrame(df_country)

# Drop rows with NaN values in the 'country' column
df_country.dropna(subset=['country'], inplace=True)
print(type(df_country))
print(df_country)


#rename columns
country_counts = pd.DataFrame(df_country['country'].value_counts())
country_counts.reset_index(inplace=True)
country_counts.columns = ['iso_a3', 'Count']
country_counts.set_index('iso_a3', inplace=True)

num_nan_rows = df_country.isna().sum()
print(f"Number of rows with NaN values: {num_nan_rows}")
print(country_counts.head(), type(country_counts))
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    country
# 0      USA
# 1      GHA
# 2      UKR
# 3      GRC
# 4      N/A
# ..     ...
# 94     N/A
# 95     N/A
# 96     CHN
# 97     PHL
# 98     AUS
#
# [99 rows x 1 columns]
# Number of rows with NaN values: country    0
# dtype: int64
#         Count
# iso_a3
# CHN        23
# N/A        12
# IDN         8
# POL         7
# PHL         5 <class 'pandas.core.frame.DataFrame'>

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cm

# load the world map shapefile
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# create a dummy dataset with country codes and counts
#country_counts = pd.DataFrame({'iso_a3': ['CAN', 'USA', 'MEX'], 'Count': [10, 5, 15]})

# merge the counts with the world map shapefile
merged = world_map.merge(country_counts, left_on='iso_a3', right_index=True, how='left')

# fill any missing counts with 0
merged['Count'].fillna(0, inplace=True)

# create a ListedColormap from the OrRd colormap
cmap = cm.get_cmap('OrRd', 5)
cmap_list = [cmap(i) for i in range(cmap.N)]
new_cmap = colors.ListedColormap(cmap_list)

# plot the heat map
fig, ax = plt.subplots(figsize=(10, 6))
merged.plot(column='Count', cmap=new_cmap, linewidth=0.8, ax=ax, edgecolor='0.8', norm=colors.LogNorm(vmin=1, vmax=25))

# add colorbar
sm = plt.cm.ScalarMappable(cmap=new_cmap, norm=colors.Normalize(vmin=1, vmax=25))
sm._A = []
cbar = plt.colorbar(sm, ax=ax, shrink=0.5)
cbar.ax.set_ylabel('Count of people by country')

ax.axis('off')
ax.set_title('Where in the world do your classmates live?')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_1140\1453024387.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('OrRd', 5)

# %% [markdown]
# ## Author
#
# <a href="https://www.linkedin.com/in/ravahuja/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">Rav Ahuja</a>
#
# <a href="https://www.linkedin.com/in/lakshmi-holla-b39062149/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">Lakshmi Holla</a>
#
#
#
# ## Other Contributor(s)
#
# <a href="https://www.linkedin.com/in/malika-goyal-04798622/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">Malika</a>
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                 |
# | ----------------- | ------- | ---------- | ---------------------------------- |
# | 2022-03-04        | 1.0     | Lakshmi Holla     | Created lab using sqlite3          |
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2022. All rights reserved. <h3/>
